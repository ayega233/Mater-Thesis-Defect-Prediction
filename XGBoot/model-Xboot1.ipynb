# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd
import joblib
from sklearn.metrics import precision_score, recall_score, roc_auc_score, roc_curve, classification_report
import os

# %%
train_repos = [
"airflow", "ansible", "black", "celery", "core", "cpython", "django", "jax",
"lightning", "localstack", "numpy", "openpilot", "pandas", "pipenv", "poetry",
"ray", "redash", "scikit-learn", "sentry","scrapy", "spaCy", "transformers", "yolov5"
]

# %%
train_df = []
for  re in train_repos:
    train_data= pd.read_csv(f"D:/MSC/SEMESTER3/TextMining/Labs/myenv/fea_train/{re}.csv")
    print(len(train_data))
    train_df.append(train_data)

combined_df = pd.concat(train_df, ignore_index=True)
print(len(combined_df))
# Out:
# 23232
# 74518
# 715
# 5714
# 54235
# 8103
# 15398
# 1089
# 15256
# 2495
# 1356
# 2082
# 21801
# 170
# 3196
# 46008
# 805
# 12076
# 23122
# 599
# 3442
# 2261
# 1666
# 319339

# %%
X_train = combined_df.iloc[:, :-1]
train_count =combined_df.shape[0]
# X_train = X_train.drop(columns=["num_changes"])
y_train = combined_df.iloc[:, -1]

# %%
val_df = []
for  re in train_repos:
    val_data= pd.read_csv(f"D:/MSC/SEMESTER3/TextMining/Labs/myenv/fea_val/{re}.csv")
    val_df.append(val_data)
combined_dfv = pd.concat(val_df, ignore_index=True)

X_val = combined_dfv.iloc[:, :-1]
val_count =combined_dfv.shape[0]
# X_train = X_train.drop(columns=["num_changes"])
y_val = combined_dfv.iloc[:, -1]

# %%
test_df = []
for  re in train_repos:
    test_data= pd.read_csv(f"D:/MSC/SEMESTER3/TextMining/Labs/myenv/fea_test/{re}.csv")
    test_df.append(test_data)
combined_dft = pd.concat(test_df, ignore_index=True)

X_test = combined_dft.iloc[:, :-1]
test_count =combined_dft.shape[0]
# X_train = X_train.drop(columns=["num_changes"])
y_test = combined_dft.iloc[:, -1]

# %%
model = xgb.XGBClassifier(
             n_estimators=1000,
            learning_rate=0.05,
            max_depth=6,
            subsample=0.8,
            colsample_bytree=0.8,
            reg_alpha=1.0,     # L1 regularization (important for sparse)
            reg_lambda=1.0,    # L2 regularization
            tree_method="hist",  # use "gpu_hist" if you have a GPU
            n_jobs=-1,
            use_label_encoder=False,
            eval_metric="logloss"
        )

model.fit(X_train, y_train,
            eval_set=[(X_val, y_val)],
            verbose=True)
# Out:
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [20:22:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# [0]	validation_0-logloss:0.47270
# [1]	validation_0-logloss:0.45109
# [2]	validation_0-logloss:0.43190
# [3]	validation_0-logloss:0.41405
# [4]	validation_0-logloss:0.39693
# [5]	validation_0-logloss:0.38099
# [6]	validation_0-logloss:0.36640
# [7]	validation_0-logloss:0.35303
# [8]	validation_0-logloss:0.34030
# [9]	validation_0-logloss:0.32814
# [10]	validation_0-logloss:0.31718
# [11]	validation_0-logloss:0.30667
# [12]	validation_0-logloss:0.29698
# [13]	validation_0-logloss:0.28767
# [14]	validation_0-logloss:0.27896
# [15]	validation_0-logloss:0.27072
# [16]	validation_0-logloss:0.26291
# [17]	validation_0-logloss:0.25575
# [18]	validation_0-logloss:0.24885
# [19]	validation_0-logloss:0.24217
# [20]	validation_0-logloss:0.23605
# [21]	validation_0-logloss:0.23017
# [22]	validation_0-logloss:0.22453
# [23]	validation_0-logloss:0.21915
# [24]	validation_0-logloss:0.21413
# [25]	validation_0-logloss:0.20946
# [26]	validation_0-logloss:0.20474
# [27]	validation_0-logloss:0.20041
# [28]	validation_0-logloss:0.19627
# [29]	validation_0-logloss:0.19231
# [30]	validation_0-logloss:0.18856
# [31]	validation_0-logloss:0.18494
# [32]	validation_0-logloss:0.18151
# [33]	validation_0-logloss:0.17837
# [34]	validation_0-logloss:0.17536
# [35]	validation_0-logloss:0.17257
# [36]	validation_0-logloss:0.16972
# [37]	validation_0-logloss:0.16702
# [38]	validation_0-logloss:0.16454
# [39]	validation_0-logloss:0.16217
# [40]	validation_0-logloss:0.15999
# [41]	validation_0-logloss:0.15766
# [42]	validation_0-logloss:0.15552
# [43]	validation_0-logloss:0.15346
# [44]	validation_0-logloss:0.15162
# [45]	validation_0-logloss:0.14980
# [46]	validation_0-logloss:0.14818
# [47]	validation_0-logloss:0.14638
# [48]	validation_0-logloss:0.14477
# [49]	validation_0-logloss:0.14314
# [50]	validation_0-logloss:0.14157
# [51]	validation_0-logloss:0.14007
# [52]	validation_0-logloss:0.13870
# [53]	validation_0-logloss:0.13723
# [54]	validation_0-logloss:0.13590
# [55]	validation_0-logloss:0.13464
# [56]	validation_0-logloss:0.13344
# [57]	validation_0-logloss:0.13232
# [58]	validation_0-logloss:0.13125
# [59]	validation_0-logloss:0.13014
# [60]	validation_0-logloss:0.12915
# [61]	validation_0-logloss:0.12819
# [62]	validation_0-logloss:0.12722
# [63]	validation_0-logloss:0.12633
# [64]	validation_0-logloss:0.12536
# [65]	validation_0-logloss:0.12454
# [66]	validation_0-logloss:0.12371
# [67]	validation_0-logloss:0.12282
# [68]	validation_0-logloss:0.12210
# [69]	validation_0-logloss:0.12132
# [70]	validation_0-logloss:0.12048
# [71]	validation_0-logloss:0.11974
# [72]	validation_0-logloss:0.11913
# [73]	validation_0-logloss:0.11848
# [74]	validation_0-logloss:0.11791
# [75]	validation_0-logloss:0.11725
# [76]	validation_0-logloss:0.11660
# [77]	validation_0-logloss:0.11604
# [78]	validation_0-logloss:0.11558
# [79]	validation_0-logloss:0.11501
# [80]	validation_0-logloss:0.11438
# [81]	validation_0-logloss:0.11379
# [82]	validation_0-logloss:0.11321
# [83]	validation_0-logloss:0.11271
# [84]	validation_0-logloss:0.11225
# [85]	validation_0-logloss:0.11175
# [86]	validation_0-logloss:0.11141
# [87]	validation_0-logloss:0.11097
# [88]	validation_0-logloss:0.11053
# [89]	validation_0-logloss:0.11007
# [90]	validation_0-logloss:0.10968
# [91]	validation_0-logloss:0.10924
# [92]	validation_0-logloss:0.10884
# [93]	validation_0-logloss:0.10842
# [94]	validation_0-logloss:0.10811
# [95]	validation_0-logloss:0.10780
# [96]	validation_0-logloss:0.10735
# [97]	validation_0-logloss:0.10701
# [98]	validation_0-logloss:0.10659
# [99]	validation_0-logloss:0.10630
# [100]	validation_0-logloss:0.10602
# [101]	validation_0-logloss:0.10569
# [102]	validation_0-logloss:0.10540
# [103]	validation_0-logloss:0.10498
# [104]	validation_0-logloss:0.10462
# [105]	validation_0-logloss:0.10435
# [106]	validation_0-logloss:0.10404
# [107]	validation_0-logloss:0.10381
# [108]	validation_0-logloss:0.10352
# [109]	validation_0-logloss:0.10330
# [110]	validation_0-logloss:0.10309
# [111]	validation_0-logloss:0.10288
# [112]	validation_0-logloss:0.10268
# [113]	validation_0-logloss:0.10247
# [114]	validation_0-logloss:0.10227
# [115]	validation_0-logloss:0.10209
# [116]	validation_0-logloss:0.10186
# [117]	validation_0-logloss:0.10170
# [118]	validation_0-logloss:0.10144
# [119]	validation_0-logloss:0.10115
# [120]	validation_0-logloss:0.10090
# [121]	validation_0-logloss:0.10065
# [122]	validation_0-logloss:0.10046
# [123]	validation_0-logloss:0.10034
# [124]	validation_0-logloss:0.10015
# [125]	validation_0-logloss:0.09995
# [126]	validation_0-logloss:0.09970
# [127]	validation_0-logloss:0.09954
# [128]	validation_0-logloss:0.09938
# [129]	validation_0-logloss:0.09917
# [130]	validation_0-logloss:0.09900
# [131]	validation_0-logloss:0.09882
# [132]	validation_0-logloss:0.09862
# [133]	validation_0-logloss:0.09840
# [134]	validation_0-logloss:0.09821
# [135]	validation_0-logloss:0.09812
# [136]	validation_0-logloss:0.09803
# [137]	validation_0-logloss:0.09790
# [138]	validation_0-logloss:0.09780
# [139]	validation_0-logloss:0.09765
# [140]	validation_0-logloss:0.09745
# [141]	validation_0-logloss:0.09738
# [142]	validation_0-logloss:0.09723
# [143]	validation_0-logloss:0.09707
# [144]	validation_0-logloss:0.09690
# [145]	validation_0-logloss:0.09674
# [146]	validation_0-logloss:0.09662
# [147]	validation_0-logloss:0.09645
# [148]	validation_0-logloss:0.09630
# [149]	validation_0-logloss:0.09628
# [150]	validation_0-logloss:0.09602
# [151]	validation_0-logloss:0.09592
# [152]	validation_0-logloss:0.09577
# [153]	validation_0-logloss:0.09568
# [154]	validation_0-logloss:0.09556
# [155]	validation_0-logloss:0.09541
# [156]	validation_0-logloss:0.09526
# [157]	validation_0-logloss:0.09518
# [158]	validation_0-logloss:0.09513
# [159]	validation_0-logloss:0.09502
# [160]	validation_0-logloss:0.09495
# [161]	validation_0-logloss:0.09481
# [162]	validation_0-logloss:0.09467
# [163]	validation_0-logloss:0.09462
# [164]	validation_0-logloss:0.09451
# [165]	validation_0-logloss:0.09441
# [166]	validation_0-logloss:0.09431
# [167]	validation_0-logloss:0.09425
# [168]	validation_0-logloss:0.09409
# [169]	validation_0-logloss:0.09394
# [170]	validation_0-logloss:0.09388
# [171]	validation_0-logloss:0.09377
# [172]	validation_0-logloss:0.09365
# [173]	validation_0-logloss:0.09357
# [174]	validation_0-logloss:0.09343
# [175]	validation_0-logloss:0.09336
# [176]	validation_0-logloss:0.09325
# [177]	validation_0-logloss:0.09313
# [178]	validation_0-logloss:0.09299
# [179]	validation_0-logloss:0.09292
# [180]	validation_0-logloss:0.09286
# [181]	validation_0-logloss:0.09271
# [182]	validation_0-logloss:0.09267
# [183]	validation_0-logloss:0.09251
# [184]	validation_0-logloss:0.09239
# [185]	validation_0-logloss:0.09225
# [186]	validation_0-logloss:0.09215
# [187]	validation_0-logloss:0.09208
# [188]	validation_0-logloss:0.09198
# [189]	validation_0-logloss:0.09191
# [190]	validation_0-logloss:0.09180
# [191]	validation_0-logloss:0.09169
# [192]	validation_0-logloss:0.09170
# [193]	validation_0-logloss:0.09158
# [194]	validation_0-logloss:0.09150
# [195]	validation_0-logloss:0.09142
# [196]	validation_0-logloss:0.09134
# [197]	validation_0-logloss:0.09127
# [198]	validation_0-logloss:0.09119
# [199]	validation_0-logloss:0.09110
# [200]	validation_0-logloss:0.09104
# [201]	validation_0-logloss:0.09096
# [202]	validation_0-logloss:0.09091
# [203]	validation_0-logloss:0.09084
# [204]	validation_0-logloss:0.09075
# [205]	validation_0-logloss:0.09067
# [206]	validation_0-logloss:0.09057
# [207]	validation_0-logloss:0.09048
# [208]	validation_0-logloss:0.09049
# [209]	validation_0-logloss:0.09045
# [210]	validation_0-logloss:0.09038
# [211]	validation_0-logloss:0.09035
# [212]	validation_0-logloss:0.09029
# [213]	validation_0-logloss:0.09026
# [214]	validation_0-logloss:0.09018
# [215]	validation_0-logloss:0.09018
# [216]	validation_0-logloss:0.09008
# [217]	validation_0-logloss:0.08999
# [218]	validation_0-logloss:0.08994
# [219]	validation_0-logloss:0.08985
# [220]	validation_0-logloss:0.08976
# [221]	validation_0-logloss:0.08977
# [222]	validation_0-logloss:0.08968
# [223]	validation_0-logloss:0.08959
# [224]	validation_0-logloss:0.08958
# [225]	validation_0-logloss:0.08948
# [226]	validation_0-logloss:0.08936
# [227]	validation_0-logloss:0.08925
# [228]	validation_0-logloss:0.08919
# [229]	validation_0-logloss:0.08915
# [230]	validation_0-logloss:0.08906
# [231]	validation_0-logloss:0.08903
# [232]	validation_0-logloss:0.08895
# [233]	validation_0-logloss:0.08889
# [234]	validation_0-logloss:0.08885
# [235]	validation_0-logloss:0.08880
# [236]	validation_0-logloss:0.08873
# [237]	validation_0-logloss:0.08870
# [238]	validation_0-logloss:0.08861
# [239]	validation_0-logloss:0.08859
# [240]	validation_0-logloss:0.08848
# [241]	validation_0-logloss:0.08843
# [242]	validation_0-logloss:0.08846
# [243]	validation_0-logloss:0.08838
# [244]	validation_0-logloss:0.08832
# [245]	validation_0-logloss:0.08824
# [246]	validation_0-logloss:0.08818
# [247]	validation_0-logloss:0.08816
# [248]	validation_0-logloss:0.08816
# [249]	validation_0-logloss:0.08818
# [250]	validation_0-logloss:0.08814
# [251]	validation_0-logloss:0.08810
# [252]	validation_0-logloss:0.08807
# [253]	validation_0-logloss:0.08801
# [254]	validation_0-logloss:0.08793
# [255]	validation_0-logloss:0.08788
# [256]	validation_0-logloss:0.08784
# [257]	validation_0-logloss:0.08779
# [258]	validation_0-logloss:0.08773
# [259]	validation_0-logloss:0.08771
# [260]	validation_0-logloss:0.08766
# [261]	validation_0-logloss:0.08759
# [262]	validation_0-logloss:0.08749
# [263]	validation_0-logloss:0.08743
# [264]	validation_0-logloss:0.08739
# [265]	validation_0-logloss:0.08736
# [266]	validation_0-logloss:0.08730
# [267]	validation_0-logloss:0.08725
# [268]	validation_0-logloss:0.08720
# [269]	validation_0-logloss:0.08714
# [270]	validation_0-logloss:0.08708
# [271]	validation_0-logloss:0.08703
# [272]	validation_0-logloss:0.08698
# [273]	validation_0-logloss:0.08687
# [274]	validation_0-logloss:0.08678
# [275]	validation_0-logloss:0.08674
# [276]	validation_0-logloss:0.08667
# [277]	validation_0-logloss:0.08667
# [278]	validation_0-logloss:0.08661
# [279]	validation_0-logloss:0.08662
# [280]	validation_0-logloss:0.08653
# [281]	validation_0-logloss:0.08648
# [282]	validation_0-logloss:0.08643
# [283]	validation_0-logloss:0.08635
# [284]	validation_0-logloss:0.08637
# [285]	validation_0-logloss:0.08633
# [286]	validation_0-logloss:0.08631
# [287]	validation_0-logloss:0.08630
# [288]	validation_0-logloss:0.08627
# [289]	validation_0-logloss:0.08622
# [290]	validation_0-logloss:0.08615
# [291]	validation_0-logloss:0.08609
# [292]	validation_0-logloss:0.08604
# [293]	validation_0-logloss:0.08599
# [294]	validation_0-logloss:0.08597
# [295]	validation_0-logloss:0.08591
# [296]	validation_0-logloss:0.08588
# [297]	validation_0-logloss:0.08581
# [298]	validation_0-logloss:0.08573
# [299]	validation_0-logloss:0.08568
# [300]	validation_0-logloss:0.08566
# [301]	validation_0-logloss:0.08568
# [302]	validation_0-logloss:0.08567
# [303]	validation_0-logloss:0.08561
# [304]	validation_0-logloss:0.08556
# [305]	validation_0-logloss:0.08553
# [306]	validation_0-logloss:0.08552
# [307]	validation_0-logloss:0.08548
# [308]	validation_0-logloss:0.08546
# [309]	validation_0-logloss:0.08542
# [310]	validation_0-logloss:0.08535
# [311]	validation_0-logloss:0.08532
# [312]	validation_0-logloss:0.08528
# [313]	validation_0-logloss:0.08525
# [314]	validation_0-logloss:0.08524
# [315]	validation_0-logloss:0.08518
# [316]	validation_0-logloss:0.08515
# [317]	validation_0-logloss:0.08509
# [318]	validation_0-logloss:0.08504
# [319]	validation_0-logloss:0.08503
# [320]	validation_0-logloss:0.08498
# [321]	validation_0-logloss:0.08502
# [322]	validation_0-logloss:0.08495
# [323]	validation_0-logloss:0.08492
# [324]	validation_0-logloss:0.08494
# [325]	validation_0-logloss:0.08491
# [326]	validation_0-logloss:0.08487
# [327]	validation_0-logloss:0.08485
# [328]	validation_0-logloss:0.08480
# [329]	validation_0-logloss:0.08477
# [330]	validation_0-logloss:0.08474
# [331]	validation_0-logloss:0.08472
# [332]	validation_0-logloss:0.08473
# [333]	validation_0-logloss:0.08473
# [334]	validation_0-logloss:0.08465
# [335]	validation_0-logloss:0.08461
# [336]	validation_0-logloss:0.08458
# [337]	validation_0-logloss:0.08453
# [338]	validation_0-logloss:0.08448
# [339]	validation_0-logloss:0.08446
# [340]	validation_0-logloss:0.08442
# [341]	validation_0-logloss:0.08444
# [342]	validation_0-logloss:0.08439
# [343]	validation_0-logloss:0.08439
# [344]	validation_0-logloss:0.08434
# [345]	validation_0-logloss:0.08435
# [346]	validation_0-logloss:0.08433
# [347]	validation_0-logloss:0.08430
# [348]	validation_0-logloss:0.08426
# [349]	validation_0-logloss:0.08424
# [350]	validation_0-logloss:0.08417
# [351]	validation_0-logloss:0.08417
# [352]	validation_0-logloss:0.08414
# [353]	validation_0-logloss:0.08410
# [354]	validation_0-logloss:0.08408
# [355]	validation_0-logloss:0.08405
# [356]	validation_0-logloss:0.08401
# [357]	validation_0-logloss:0.08395
# [358]	validation_0-logloss:0.08388
# [359]	validation_0-logloss:0.08385
# [360]	validation_0-logloss:0.08386
# [361]	validation_0-logloss:0.08381
# [362]	validation_0-logloss:0.08384
# [363]	validation_0-logloss:0.08380
# [364]	validation_0-logloss:0.08372
# [365]	validation_0-logloss:0.08372
# [366]	validation_0-logloss:0.08373
# [367]	validation_0-logloss:0.08369
# [368]	validation_0-logloss:0.08367
# [369]	validation_0-logloss:0.08364
# [370]	validation_0-logloss:0.08365
# [371]	validation_0-logloss:0.08358
# [372]	validation_0-logloss:0.08360
# [373]	validation_0-logloss:0.08358
# [374]	validation_0-logloss:0.08358
# [375]	validation_0-logloss:0.08355
# [376]	validation_0-logloss:0.08354
# [377]	validation_0-logloss:0.08355
# [378]	validation_0-logloss:0.08353
# [379]	validation_0-logloss:0.08349
# [380]	validation_0-logloss:0.08342
# [381]	validation_0-logloss:0.08342
# [382]	validation_0-logloss:0.08340
# [383]	validation_0-logloss:0.08329
# [384]	validation_0-logloss:0.08326
# [385]	validation_0-logloss:0.08325
# [386]	validation_0-logloss:0.08322
# [387]	validation_0-logloss:0.08319
# [388]	validation_0-logloss:0.08318
# [389]	validation_0-logloss:0.08317
# [390]	validation_0-logloss:0.08317
# [391]	validation_0-logloss:0.08314
# [392]	validation_0-logloss:0.08307
# [393]	validation_0-logloss:0.08305
# [394]	validation_0-logloss:0.08301
# [395]	validation_0-logloss:0.08297
# [396]	validation_0-logloss:0.08294
# [397]	validation_0-logloss:0.08288
# [398]	validation_0-logloss:0.08287
# [399]	validation_0-logloss:0.08287
# [400]	validation_0-logloss:0.08279
# [401]	validation_0-logloss:0.08278
# [402]	validation_0-logloss:0.08275
# [403]	validation_0-logloss:0.08268
# [404]	validation_0-logloss:0.08266
# [405]	validation_0-logloss:0.08263
# [406]	validation_0-logloss:0.08262
# [407]	validation_0-logloss:0.08262
# [408]	validation_0-logloss:0.08261
# [409]	validation_0-logloss:0.08254
# [410]	validation_0-logloss:0.08251
# [411]	validation_0-logloss:0.08246
# [412]	validation_0-logloss:0.08244
# [413]	validation_0-logloss:0.08242
# [414]	validation_0-logloss:0.08243
# [415]	validation_0-logloss:0.08240
# [416]	validation_0-logloss:0.08238
# [417]	validation_0-logloss:0.08237
# [418]	validation_0-logloss:0.08234
# [419]	validation_0-logloss:0.08228
# [420]	validation_0-logloss:0.08227
# [421]	validation_0-logloss:0.08228
# [422]	validation_0-logloss:0.08221
# [423]	validation_0-logloss:0.08220
# [424]	validation_0-logloss:0.08220
# [425]	validation_0-logloss:0.08214
# [426]	validation_0-logloss:0.08210
# [427]	validation_0-logloss:0.08210
# [428]	validation_0-logloss:0.08210
# [429]	validation_0-logloss:0.08209
# [430]	validation_0-logloss:0.08214
# [431]	validation_0-logloss:0.08217
# [432]	validation_0-logloss:0.08215
# [433]	validation_0-logloss:0.08217
# [434]	validation_0-logloss:0.08217
# [435]	validation_0-logloss:0.08215
# [436]	validation_0-logloss:0.08218
# [437]	validation_0-logloss:0.08217
# [438]	validation_0-logloss:0.08213
# [439]	validation_0-logloss:0.08211
# [440]	validation_0-logloss:0.08209
# [441]	validation_0-logloss:0.08208
# [442]	validation_0-logloss:0.08212
# [443]	validation_0-logloss:0.08208
# [444]	validation_0-logloss:0.08206
# [445]	validation_0-logloss:0.08205
# [446]	validation_0-logloss:0.08199
# [447]	validation_0-logloss:0.08203
# [448]	validation_0-logloss:0.08201
# [449]	validation_0-logloss:0.08202
# [450]	validation_0-logloss:0.08200
# [451]	validation_0-logloss:0.08199
# [452]	validation_0-logloss:0.08192
# [453]	validation_0-logloss:0.08192
# [454]	validation_0-logloss:0.08193
# [455]	validation_0-logloss:0.08193
# [456]	validation_0-logloss:0.08188
# [457]	validation_0-logloss:0.08192
# [458]	validation_0-logloss:0.08193
# [459]	validation_0-logloss:0.08198
# [460]	validation_0-logloss:0.08196
# [461]	validation_0-logloss:0.08194
# [462]	validation_0-logloss:0.08194
# [463]	validation_0-logloss:0.08188
# [464]	validation_0-logloss:0.08193
# [465]	validation_0-logloss:0.08191
# [466]	validation_0-logloss:0.08190
# [467]	validation_0-logloss:0.08193
# [468]	validation_0-logloss:0.08192
# [469]	validation_0-logloss:0.08189
# [470]	validation_0-logloss:0.08190
# [471]	validation_0-logloss:0.08184
# [472]	validation_0-logloss:0.08175
# [473]	validation_0-logloss:0.08174
# [474]	validation_0-logloss:0.08173
# [475]	validation_0-logloss:0.08172
# [476]	validation_0-logloss:0.08169
# [477]	validation_0-logloss:0.08165
# [478]	validation_0-logloss:0.08157
# [479]	validation_0-logloss:0.08156
# [480]	validation_0-logloss:0.08153
# [481]	validation_0-logloss:0.08152
# [482]	validation_0-logloss:0.08148
# [483]	validation_0-logloss:0.08151
# [484]	validation_0-logloss:0.08148
# [485]	validation_0-logloss:0.08145
# [486]	validation_0-logloss:0.08146
# [487]	validation_0-logloss:0.08142
# [488]	validation_0-logloss:0.08140
# [489]	validation_0-logloss:0.08142
# [490]	validation_0-logloss:0.08141
# [491]	validation_0-logloss:0.08138
# [492]	validation_0-logloss:0.08136
# [493]	validation_0-logloss:0.08137
# [494]	validation_0-logloss:0.08138
# [495]	validation_0-logloss:0.08137
# [496]	validation_0-logloss:0.08133
# [497]	validation_0-logloss:0.08133
# [498]	validation_0-logloss:0.08129
# [499]	validation_0-logloss:0.08126
# [500]	validation_0-logloss:0.08124
# [501]	validation_0-logloss:0.08127
# [502]	validation_0-logloss:0.08125
# [503]	validation_0-logloss:0.08125
# [504]	validation_0-logloss:0.08122
# [505]	validation_0-logloss:0.08123
# [506]	validation_0-logloss:0.08122
# [507]	validation_0-logloss:0.08125
# [508]	validation_0-logloss:0.08121
# [509]	validation_0-logloss:0.08117
# [510]	validation_0-logloss:0.08124
# [511]	validation_0-logloss:0.08126
# [512]	validation_0-logloss:0.08120
# [513]	validation_0-logloss:0.08116
# [514]	validation_0-logloss:0.08116
# [515]	validation_0-logloss:0.08118
# [516]	validation_0-logloss:0.08118
# [517]	validation_0-logloss:0.08115
# [518]	validation_0-logloss:0.08112
# [519]	validation_0-logloss:0.08111
# [520]	validation_0-logloss:0.08111
# [521]	validation_0-logloss:0.08112
# [522]	validation_0-logloss:0.08113
# [523]	validation_0-logloss:0.08110
# [524]	validation_0-logloss:0.08108
# [525]	validation_0-logloss:0.08109
# [526]	validation_0-logloss:0.08110
# [527]	validation_0-logloss:0.08105
# [528]	validation_0-logloss:0.08101
# [529]	validation_0-logloss:0.08099
# [530]	validation_0-logloss:0.08100
# [531]	validation_0-logloss:0.08099
# [532]	validation_0-logloss:0.08096
# [533]	validation_0-logloss:0.08095
# [534]	validation_0-logloss:0.08092
# [535]	validation_0-logloss:0.08087
# [536]	validation_0-logloss:0.08087
# [537]	validation_0-logloss:0.08086
# [538]	validation_0-logloss:0.08083
# [539]	validation_0-logloss:0.08081
# [540]	validation_0-logloss:0.08081
# [541]	validation_0-logloss:0.08080
# [542]	validation_0-logloss:0.08079
# [543]	validation_0-logloss:0.08078
# [544]	validation_0-logloss:0.08077
# [545]	validation_0-logloss:0.08074
# [546]	validation_0-logloss:0.08074
# [547]	validation_0-logloss:0.08073
# [548]	validation_0-logloss:0.08074
# [549]	validation_0-logloss:0.08073
# [550]	validation_0-logloss:0.08072
# [551]	validation_0-logloss:0.08072
# [552]	validation_0-logloss:0.08068
# [553]	validation_0-logloss:0.08070
# [554]	validation_0-logloss:0.08071
# [555]	validation_0-logloss:0.08069
# [556]	validation_0-logloss:0.08066
# [557]	validation_0-logloss:0.08067
# [558]	validation_0-logloss:0.08068
# [559]	validation_0-logloss:0.08066
# [560]	validation_0-logloss:0.08062
# [561]	validation_0-logloss:0.08059
# [562]	validation_0-logloss:0.08061
# [563]	validation_0-logloss:0.08058
# [564]	validation_0-logloss:0.08056
# [565]	validation_0-logloss:0.08057
# [566]	validation_0-logloss:0.08060
# [567]	validation_0-logloss:0.08062
# [568]	validation_0-logloss:0.08058
# [569]	validation_0-logloss:0.08059
# [570]	validation_0-logloss:0.08059
# [571]	validation_0-logloss:0.08055
# [572]	validation_0-logloss:0.08053
# [573]	validation_0-logloss:0.08051
# [574]	validation_0-logloss:0.08050
# [575]	validation_0-logloss:0.08046
# [576]	validation_0-logloss:0.08045
# [577]	validation_0-logloss:0.08043
# [578]	validation_0-logloss:0.08038
# [579]	validation_0-logloss:0.08038
# [580]	validation_0-logloss:0.08035
# [581]	validation_0-logloss:0.08032
# [582]	validation_0-logloss:0.08030
# [583]	validation_0-logloss:0.08024
# [584]	validation_0-logloss:0.08018
# [585]	validation_0-logloss:0.08017
# [586]	validation_0-logloss:0.08015
# [587]	validation_0-logloss:0.08013
# [588]	validation_0-logloss:0.08013
# [589]	validation_0-logloss:0.08011
# [590]	validation_0-logloss:0.08010
# [591]	validation_0-logloss:0.08012
# [592]	validation_0-logloss:0.08011
# [593]	validation_0-logloss:0.08008
# [594]	validation_0-logloss:0.08006
# [595]	validation_0-logloss:0.08008
# [596]	validation_0-logloss:0.08008
# [597]	validation_0-logloss:0.08009
# [598]	validation_0-logloss:0.08006
# [599]	validation_0-logloss:0.08006
# [600]	validation_0-logloss:0.08013
# [601]	validation_0-logloss:0.08010
# [602]	validation_0-logloss:0.08010
# [603]	validation_0-logloss:0.08005
# [604]	validation_0-logloss:0.07999
# [605]	validation_0-logloss:0.07996
# [606]	validation_0-logloss:0.07995
# [607]	validation_0-logloss:0.07995
# [608]	validation_0-logloss:0.07992
# [609]	validation_0-logloss:0.07987
# [610]	validation_0-logloss:0.07985
# [611]	validation_0-logloss:0.07982
# [612]	validation_0-logloss:0.07982
# [613]	validation_0-logloss:0.07981
# [614]	validation_0-logloss:0.07983
# [615]	validation_0-logloss:0.07984
# [616]	validation_0-logloss:0.07981
# [617]	validation_0-logloss:0.07981
# [618]	validation_0-logloss:0.07978
# [619]	validation_0-logloss:0.07975
# [620]	validation_0-logloss:0.07977
# [621]	validation_0-logloss:0.07974
# [622]	validation_0-logloss:0.07967
# [623]	validation_0-logloss:0.07963
# [624]	validation_0-logloss:0.07961
# [625]	validation_0-logloss:0.07960
# [626]	validation_0-logloss:0.07961
# [627]	validation_0-logloss:0.07957
# [628]	validation_0-logloss:0.07953
# [629]	validation_0-logloss:0.07952
# [630]	validation_0-logloss:0.07955
# [631]	validation_0-logloss:0.07953
# [632]	validation_0-logloss:0.07955
# [633]	validation_0-logloss:0.07957
# [634]	validation_0-logloss:0.07958
# [635]	validation_0-logloss:0.07956
# [636]	validation_0-logloss:0.07953
# [637]	validation_0-logloss:0.07955
# [638]	validation_0-logloss:0.07953
# [639]	validation_0-logloss:0.07952
# [640]	validation_0-logloss:0.07954
# [641]	validation_0-logloss:0.07954
# [642]	validation_0-logloss:0.07950
# [643]	validation_0-logloss:0.07949
# [644]	validation_0-logloss:0.07948
# [645]	validation_0-logloss:0.07947
# [646]	validation_0-logloss:0.07944
# [647]	validation_0-logloss:0.07943
# [648]	validation_0-logloss:0.07941
# [649]	validation_0-logloss:0.07939
# [650]	validation_0-logloss:0.07939
# [651]	validation_0-logloss:0.07940
# [652]	validation_0-logloss:0.07940
# [653]	validation_0-logloss:0.07941
# [654]	validation_0-logloss:0.07944
# [655]	validation_0-logloss:0.07942
# [656]	validation_0-logloss:0.07942
# [657]	validation_0-logloss:0.07942
# [658]	validation_0-logloss:0.07942
# [659]	validation_0-logloss:0.07941
# [660]	validation_0-logloss:0.07942
# [661]	validation_0-logloss:0.07937
# [662]	validation_0-logloss:0.07939
# [663]	validation_0-logloss:0.07936
# [664]	validation_0-logloss:0.07937
# [665]	validation_0-logloss:0.07936
# [666]	validation_0-logloss:0.07937
# [667]	validation_0-logloss:0.07935
# [668]	validation_0-logloss:0.07934
# [669]	validation_0-logloss:0.07934
# [670]	validation_0-logloss:0.07932
# [671]	validation_0-logloss:0.07930
# [672]	validation_0-logloss:0.07934
# [673]	validation_0-logloss:0.07940
# [674]	validation_0-logloss:0.07939
# [675]	validation_0-logloss:0.07937
# [676]	validation_0-logloss:0.07941
# [677]	validation_0-logloss:0.07940
# [678]	validation_0-logloss:0.07939
# [679]	validation_0-logloss:0.07936
# [680]	validation_0-logloss:0.07939
# [681]	validation_0-logloss:0.07940
# [682]	validation_0-logloss:0.07940
# [683]	validation_0-logloss:0.07939
# [684]	validation_0-logloss:0.07935
# [685]	validation_0-logloss:0.07933
# [686]	validation_0-logloss:0.07931
# [687]	validation_0-logloss:0.07931
# [688]	validation_0-logloss:0.07927
# [689]	validation_0-logloss:0.07924
# [690]	validation_0-logloss:0.07924
# [691]	validation_0-logloss:0.07924
# [692]	validation_0-logloss:0.07922
# [693]	validation_0-logloss:0.07917
# [694]	validation_0-logloss:0.07915
# [695]	validation_0-logloss:0.07914
# [696]	validation_0-logloss:0.07915
# [697]	validation_0-logloss:0.07912
# [698]	validation_0-logloss:0.07911
# [699]	validation_0-logloss:0.07910
# [700]	validation_0-logloss:0.07906
# [701]	validation_0-logloss:0.07907
# [702]	validation_0-logloss:0.07901
# [703]	validation_0-logloss:0.07900
# [704]	validation_0-logloss:0.07899
# [705]	validation_0-logloss:0.07894
# [706]	validation_0-logloss:0.07893
# [707]	validation_0-logloss:0.07891
# [708]	validation_0-logloss:0.07890
# [709]	validation_0-logloss:0.07888
# [710]	validation_0-logloss:0.07886
# [711]	validation_0-logloss:0.07881
# [712]	validation_0-logloss:0.07879
# [713]	validation_0-logloss:0.07878
# [714]	validation_0-logloss:0.07877
# [715]	validation_0-logloss:0.07878
# [716]	validation_0-logloss:0.07876
# [717]	validation_0-logloss:0.07875
# [718]	validation_0-logloss:0.07874
# [719]	validation_0-logloss:0.07874
# [720]	validation_0-logloss:0.07879
# [721]	validation_0-logloss:0.07878
# [722]	validation_0-logloss:0.07878
# [723]	validation_0-logloss:0.07879
# [724]	validation_0-logloss:0.07875
# [725]	validation_0-logloss:0.07873
# [726]	validation_0-logloss:0.07869
# [727]	validation_0-logloss:0.07868
# [728]	validation_0-logloss:0.07866
# [729]	validation_0-logloss:0.07864
# [730]	validation_0-logloss:0.07865
# [731]	validation_0-logloss:0.07863
# [732]	validation_0-logloss:0.07858
# [733]	validation_0-logloss:0.07857
# [734]	validation_0-logloss:0.07857
# [735]	validation_0-logloss:0.07855
# [736]	validation_0-logloss:0.07855
# [737]	validation_0-logloss:0.07854
# [738]	validation_0-logloss:0.07853
# [739]	validation_0-logloss:0.07850
# [740]	validation_0-logloss:0.07847
# [741]	validation_0-logloss:0.07847
# [742]	validation_0-logloss:0.07845
# [743]	validation_0-logloss:0.07842
# [744]	validation_0-logloss:0.07841
# [745]	validation_0-logloss:0.07842
# [746]	validation_0-logloss:0.07843
# [747]	validation_0-logloss:0.07843
# [748]	validation_0-logloss:0.07840
# [749]	validation_0-logloss:0.07842
# [750]	validation_0-logloss:0.07841
# [751]	validation_0-logloss:0.07836
# [752]	validation_0-logloss:0.07834
# [753]	validation_0-logloss:0.07829
# [754]	validation_0-logloss:0.07828
# [755]	validation_0-logloss:0.07830
# [756]	validation_0-logloss:0.07828
# [757]	validation_0-logloss:0.07833
# [758]	validation_0-logloss:0.07830
# [759]	validation_0-logloss:0.07827
# [760]	validation_0-logloss:0.07825
# [761]	validation_0-logloss:0.07822
# [762]	validation_0-logloss:0.07821
# [763]	validation_0-logloss:0.07817
# [764]	validation_0-logloss:0.07816
# [765]	validation_0-logloss:0.07821
# [766]	validation_0-logloss:0.07818
# [767]	validation_0-logloss:0.07821
# [768]	validation_0-logloss:0.07819
# [769]	validation_0-logloss:0.07815
# [770]	validation_0-logloss:0.07818
# [771]	validation_0-logloss:0.07818
# [772]	validation_0-logloss:0.07814
# [773]	validation_0-logloss:0.07813
# [774]	validation_0-logloss:0.07815
# [775]	validation_0-logloss:0.07814
# [776]	validation_0-logloss:0.07817
# [777]	validation_0-logloss:0.07815
# [778]	validation_0-logloss:0.07813
# [779]	validation_0-logloss:0.07812
# [780]	validation_0-logloss:0.07810
# [781]	validation_0-logloss:0.07807
# [782]	validation_0-logloss:0.07812
# [783]	validation_0-logloss:0.07814
# [784]	validation_0-logloss:0.07811
# [785]	validation_0-logloss:0.07811
# [786]	validation_0-logloss:0.07812
# [787]	validation_0-logloss:0.07807
# [788]	validation_0-logloss:0.07805
# [789]	validation_0-logloss:0.07806
# [790]	validation_0-logloss:0.07803
# [791]	validation_0-logloss:0.07801
# [792]	validation_0-logloss:0.07800
# [793]	validation_0-logloss:0.07803
# [794]	validation_0-logloss:0.07805
# [795]	validation_0-logloss:0.07803
# [796]	validation_0-logloss:0.07802
# [797]	validation_0-logloss:0.07808
# [798]	validation_0-logloss:0.07805
# [799]	validation_0-logloss:0.07804
# [800]	validation_0-logloss:0.07803
# [801]	validation_0-logloss:0.07800
# [802]	validation_0-logloss:0.07795
# [803]	validation_0-logloss:0.07796
# [804]	validation_0-logloss:0.07795
# [805]	validation_0-logloss:0.07798
# [806]	validation_0-logloss:0.07800
# [807]	validation_0-logloss:0.07797
# [808]	validation_0-logloss:0.07795
# [809]	validation_0-logloss:0.07791
# [810]	validation_0-logloss:0.07790
# [811]	validation_0-logloss:0.07790
# [812]	validation_0-logloss:0.07791
# [813]	validation_0-logloss:0.07792
# [814]	validation_0-logloss:0.07788
# [815]	validation_0-logloss:0.07786
# [816]	validation_0-logloss:0.07791
# [817]	validation_0-logloss:0.07788
# [818]	validation_0-logloss:0.07789
# [819]	validation_0-logloss:0.07788
# [820]	validation_0-logloss:0.07787
# [821]	validation_0-logloss:0.07787
# [822]	validation_0-logloss:0.07789
# [823]	validation_0-logloss:0.07787
# [824]	validation_0-logloss:0.07784
# [825]	validation_0-logloss:0.07786
# [826]	validation_0-logloss:0.07786
# [827]	validation_0-logloss:0.07789
# [828]	validation_0-logloss:0.07787
# [829]	validation_0-logloss:0.07786
# [830]	validation_0-logloss:0.07785
# [831]	validation_0-logloss:0.07784
# [832]	validation_0-logloss:0.07781
# [833]	validation_0-logloss:0.07782
# [834]	validation_0-logloss:0.07787
# [835]	validation_0-logloss:0.07786
# [836]	validation_0-logloss:0.07784
# [837]	validation_0-logloss:0.07785
# [838]	validation_0-logloss:0.07787
# [839]	validation_0-logloss:0.07786
# [840]	validation_0-logloss:0.07786
# [841]	validation_0-logloss:0.07787
# [842]	validation_0-logloss:0.07784
# [843]	validation_0-logloss:0.07784
# [844]	validation_0-logloss:0.07782
# [845]	validation_0-logloss:0.07782
# [846]	validation_0-logloss:0.07781
# [847]	validation_0-logloss:0.07782
# [848]	validation_0-logloss:0.07781
# [849]	validation_0-logloss:0.07780
# [850]	validation_0-logloss:0.07778
# [851]	validation_0-logloss:0.07773
# [852]	validation_0-logloss:0.07771
# [853]	validation_0-logloss:0.07771
# [854]	validation_0-logloss:0.07772
# [855]	validation_0-logloss:0.07772
# [856]	validation_0-logloss:0.07768
# [857]	validation_0-logloss:0.07767
# [858]	validation_0-logloss:0.07767
# [859]	validation_0-logloss:0.07769
# [860]	validation_0-logloss:0.07770
# [861]	validation_0-logloss:0.07767
# [862]	validation_0-logloss:0.07767
# [863]	validation_0-logloss:0.07765
# [864]	validation_0-logloss:0.07765
# [865]	validation_0-logloss:0.07764
# [866]	validation_0-logloss:0.07762
# [867]	validation_0-logloss:0.07763
# [868]	validation_0-logloss:0.07764
# [869]	validation_0-logloss:0.07763
# [870]	validation_0-logloss:0.07762
# [871]	validation_0-logloss:0.07763
# [872]	validation_0-logloss:0.07763
# [873]	validation_0-logloss:0.07761
# [874]	validation_0-logloss:0.07760
# [875]	validation_0-logloss:0.07757
# [876]	validation_0-logloss:0.07757
# [877]	validation_0-logloss:0.07759
# [878]	validation_0-logloss:0.07763
# [879]	validation_0-logloss:0.07768
# [880]	validation_0-logloss:0.07765
# [881]	validation_0-logloss:0.07762
# [882]	validation_0-logloss:0.07762
# [883]	validation_0-logloss:0.07765
# [884]	validation_0-logloss:0.07767
# [885]	validation_0-logloss:0.07764
# [886]	validation_0-logloss:0.07767
# [887]	validation_0-logloss:0.07766
# [888]	validation_0-logloss:0.07763
# [889]	validation_0-logloss:0.07764
# [890]	validation_0-logloss:0.07763
# [891]	validation_0-logloss:0.07760
# [892]	validation_0-logloss:0.07759
# [893]	validation_0-logloss:0.07759
# [894]	validation_0-logloss:0.07757
# [895]	validation_0-logloss:0.07756
# [896]	validation_0-logloss:0.07755
# [897]	validation_0-logloss:0.07757
# [898]	validation_0-logloss:0.07755
# [899]	validation_0-logloss:0.07752
# [900]	validation_0-logloss:0.07751
# [901]	validation_0-logloss:0.07748
# [902]	validation_0-logloss:0.07749
# [903]	validation_0-logloss:0.07750
# [904]	validation_0-logloss:0.07751
# [905]	validation_0-logloss:0.07748
# [906]	validation_0-logloss:0.07746
# [907]	validation_0-logloss:0.07746
# [908]	validation_0-logloss:0.07745
# [909]	validation_0-logloss:0.07741
# [910]	validation_0-logloss:0.07740
# [911]	validation_0-logloss:0.07740
# [912]	validation_0-logloss:0.07737
# [913]	validation_0-logloss:0.07740
# [914]	validation_0-logloss:0.07738
# [915]	validation_0-logloss:0.07734
# [916]	validation_0-logloss:0.07734
# [917]	validation_0-logloss:0.07734
# [918]	validation_0-logloss:0.07732
# [919]	validation_0-logloss:0.07731
# [920]	validation_0-logloss:0.07736
# [921]	validation_0-logloss:0.07736
# [922]	validation_0-logloss:0.07736
# [923]	validation_0-logloss:0.07733
# [924]	validation_0-logloss:0.07732
# [925]	validation_0-logloss:0.07731
# [926]	validation_0-logloss:0.07728
# [927]	validation_0-logloss:0.07726
# [928]	validation_0-logloss:0.07725
# [929]	validation_0-logloss:0.07723
# [930]	validation_0-logloss:0.07725
# [931]	validation_0-logloss:0.07724
# [932]	validation_0-logloss:0.07722
# [933]	validation_0-logloss:0.07720
# [934]	validation_0-logloss:0.07721
# [935]	validation_0-logloss:0.07718
# [936]	validation_0-logloss:0.07719
# [937]	validation_0-logloss:0.07719
# [938]	validation_0-logloss:0.07716
# [939]	validation_0-logloss:0.07713
# [940]	validation_0-logloss:0.07715
# [941]	validation_0-logloss:0.07713
# [942]	validation_0-logloss:0.07711
# [943]	validation_0-logloss:0.07713
# [944]	validation_0-logloss:0.07714
# [945]	validation_0-logloss:0.07715
# [946]	validation_0-logloss:0.07714
# [947]	validation_0-logloss:0.07712
# [948]	validation_0-logloss:0.07711
# [949]	validation_0-logloss:0.07712
# [950]	validation_0-logloss:0.07711
# [951]	validation_0-logloss:0.07711
# [952]	validation_0-logloss:0.07711
# [953]	validation_0-logloss:0.07715
# [954]	validation_0-logloss:0.07716
# [955]	validation_0-logloss:0.07715
# [956]	validation_0-logloss:0.07715
# [957]	validation_0-logloss:0.07715
# [958]	validation_0-logloss:0.07713
# [959]	validation_0-logloss:0.07712
# [960]	validation_0-logloss:0.07712
# [961]	validation_0-logloss:0.07709
# [962]	validation_0-logloss:0.07709
# [963]	validation_0-logloss:0.07708
# [964]	validation_0-logloss:0.07704
# [965]	validation_0-logloss:0.07702
# [966]	validation_0-logloss:0.07699
# [967]	validation_0-logloss:0.07698
# [968]	validation_0-logloss:0.07699
# [969]	validation_0-logloss:0.07697
# [970]	validation_0-logloss:0.07693
# [971]	validation_0-logloss:0.07691
# [972]	validation_0-logloss:0.07687
# [973]	validation_0-logloss:0.07688
# [974]	validation_0-logloss:0.07686
# [975]	validation_0-logloss:0.07683
# [976]	validation_0-logloss:0.07683
# [977]	validation_0-logloss:0.07681
# [978]	validation_0-logloss:0.07680
# [979]	validation_0-logloss:0.07679
# [980]	validation_0-logloss:0.07678
# [981]	validation_0-logloss:0.07675
# [982]	validation_0-logloss:0.07676
# [983]	validation_0-logloss:0.07674
# [984]	validation_0-logloss:0.07675
# [985]	validation_0-logloss:0.07674
# [986]	validation_0-logloss:0.07675
# [987]	validation_0-logloss:0.07676
# [988]	validation_0-logloss:0.07674
# [989]	validation_0-logloss:0.07671
# [990]	validation_0-logloss:0.07673
# [991]	validation_0-logloss:0.07673
# [992]	validation_0-logloss:0.07672
# [993]	validation_0-logloss:0.07669
# [994]	validation_0-logloss:0.07667
# [995]	validation_0-logloss:0.07666
# [996]	validation_0-logloss:0.07659
# [997]	validation_0-logloss:0.07659
# [998]	validation_0-logloss:0.07656
# [999]	validation_0-logloss:0.07654
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
y_train_pred = model.predict(X_train)

report_train = classification_report(y_train, y_train_pred, output_dict=True)
print("Train_Accuracy:", accuracy_score(y_train, y_train_pred))

y_val_pred = model.predict(X_val)

report_validation = classification_report(y_val, y_val_pred, output_dict=True)
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))


y_test_pred = model.predict(X_test)
# y_prob = model.predict_proba(X)[:, 1] 
report_test = classification_report(y_test, y_test_pred, output_dict=True)
print(report_test)
# print("Test Accuracy:", accuracy_score(y_test, y_test_pred))
# Out:
# Train_Accuracy: 0.9914980631867701
# Validation Accuracy: 0.976392901361948
# Test Accuracy: 0.9763388422288449

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import json
import os

# Dummy example: y_true and y_scores for each split
results = {}

# Replace these with your actual true labels and predicted probabilities

y_true = y_val  # true binary labels for split
y_score =y_val_pred # predicted probabilities for split

# AUC Score
aoc = roc_auc_score(y_true, y_score)
# results[split] = {"auc": aoc}

# ROC Curve
fpr, tpr, _ = roc_curve(y_true, y_score)

# Plot and save ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'AUC = {aoc:.2f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve - Validation')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# %%
from sklearn.metrics import roc_auc_score, roc_curve
import matplotlib.pyplot as plt
import json
import os

# Dummy example: y_true and y_scores for each split
results = {}

# Replace these with your actual true labels and predicted probabilities

y_true = y_test  # true binary labels for split
y_score =y_test_pred # predicted probabilities for split

# AUC Score
aoc = roc_auc_score(y_true, y_score)
# results[split] = {"auc": aoc}

# ROC Curve
fpr, tpr, _ = roc_curve(y_true, y_score)

# Plot and save ROC curve
plt.figure()
plt.plot(fpr, tpr, label=f'AUC = {aoc:.2f}')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC Curve - Test')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
alldata = pd.concat(combined_df, ignore_index=True)

accuracies = cross_val_score(model,X_train, y_train, cv=skf, scoring='accuracy')
print(f"Cross-validated accuracies: {accuracies}")
print(f"Mean accuracy: {accuracies.mean():.4f}")
# Out:
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [21:03:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [21:18:13] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [21:33:35] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [21:48:03] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [22:02:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# Cross-validated accuracies: [0.97137847 0.97249014 0.97310077 0.97158201 0.9717538 ]
# Mean accuracy: 0.9721

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

alldata = pd.concat([combined_df, combined_dfv,combined_dft], ignore_index=True)
X = alldata.iloc[:, :-1]
val_count =alldata.shape[0]
print(val_count)
Y = alldata.iloc[:, -1]
# Out:
# 342527

# %%
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import (
    roc_auc_score, roc_curve, precision_score,
    recall_score, f1_score, RocCurveDisplay
)
import matplotlib.pyplot as plt
import numpy as np

# Initialize Stratified K-Fold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Store metrics
accuracies = []
precisions = []
recalls = []
f1s = []
aucs = []
mean_fpr = np.linspace(0, 1, 100)
tprs = []

# Cross-validation loop
for train_idx, val_idx in skf.split(X, Y):
    # X_train, X_val = X[train_idx], X[val_idx]
    # y_train, y_val = Y[train_idx], Y[val_idx]
    X_train = X.iloc[train_idx]
    X_val = X.iloc[val_idx]
    y_train = Y.iloc[train_idx]
    y_val = Y.iloc[val_idx]
    model.fit(X_train, y_train)
    y_pred = model.predict(X_val)
    y_proba = model.predict_proba(X_val)[:, 1]
    
    # Metrics
    acc = model.score(X_val, y_val)
    precision = precision_score(y_val, y_pred)
    recall = recall_score(y_val, y_pred)
    f1 = f1_score(y_val, y_pred)
    auc = roc_auc_score(y_val, y_proba)
    
    accuracies.append(acc)
    precisions.append(precision)
    recalls.append(recall)
    f1s.append(f1)
    aucs.append(auc)
    
    # ROC curve
    fpr, tpr, _ = roc_curve(y_val, y_proba)
    tpr_interp = np.interp(mean_fpr, fpr, tpr)
    tpr_interp[0] = 0.0
    tprs.append(tpr_interp)
# Out:
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [22:51:56] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [23:09:07] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [23:25:52] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [23:42:46] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\ayega\miniconda3\envs\tbmi26_tf\lib\site-packages\xgboost\training.py:183: UserWarning: [00:03:12] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:738:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
# Print metrics
print(f"Mean Accuracy: {np.mean(accuracies):.4f}")
print(f"Mean Precision: {np.mean(precisions):.4f}")
print(f"Mean Recall: {np.mean(recalls):.4f}")
print(f"Mean F1 Score: {np.mean(f1s):.4f}")
print(f"Mean ROC AUC: {np.mean(aucs):.4f}")

# Plot average ROC curve
mean_tpr = np.mean(tprs, axis=0)
mean_tpr[-1] = 1.0
plt.figure(figsize=(8, 6))
plt.plot(mean_fpr, mean_tpr, color='b', label=f'Mean ROC (AUC = {np.mean(aucs):.4f})')
plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Cross-Validated ROC Curve")
plt.legend(loc="lower right")
plt.grid(True)
plt.show()
# Out:
# Mean Accuracy: 0.9720
# Mean Precision: 0.9790
# Mean Recall: 0.9355
# Mean F1 Score: 0.9568
# Mean ROC AUC: 0.9945
